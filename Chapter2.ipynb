# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Chapter 2: Exercises
#
# ## Conceptual

# %% [markdown]
# **1. For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.**
#
# **a.** The sample size *_n_* is extremely large, and the number of predictors *_p_* is small.
#
# > We expect the more flexible statistical learning method to perform **better** because the method can better utilize the large number of observations to possibly find a more accurate shape of _f_.
#
# **b.** The number of predictors *_p_* is extremely large, and the number of observations *_n_* is small.
#
# > A more flexible method will perform **worse** because more flexible methods typically require a large number of observations in order to obtain an accurate estimate for _f_. Many predictors coupled with few observation typically leads to overfitting for more flexible methods.
#
# **c.** The relationship between the predictors and response is highly non-linear.
#
# > A more flexible method will perform **better** because more flexible methods can find non-linear shapes of _f_.
#
# **d.** The variance of the error terms is extremely high.
#
# > A more flexible method will perform **worse** because it is more likely to fit the noise (overfit) that find the true estimate of _f_.

# %% [markdown]
# **2. Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediciton. Finally, provide *_n_* and *_p_*.**
#
# **a.** We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.
#
# > **Regression** since salary is a continous number (quantitative) and **inference** since we want understand the relationshop between the predictors (X) and the response (Y).
# * n = 500
#     * number of firms
# * p = 3
#     * record profit
#     * number of employess
#     * industry
#
# **b.** We are considering launching a new product and wish to know whether it will be a _success_ or a _failure_. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.
#
# > **Classification** since it is a qualitative response. **Prediction** since we most care about predicting whether our product will be a success or failure.
# * n = 20
#     * similar products that were previously launced
# * p = 13
#     * price charged
#     * marketing budget
#     * competition price
#     * 10 other variables
#
# **c.** We are interesting in predicting the % change in the US dollar in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the dollar, the % change in the US market, the % change in the British market, and the % change in the German market.
#
# > **Regression** since it is a quantitative response. **Prediction** since we are concerned with _predicting_ the % change in the US dollar.
# * n = 52
#     * weekly data for all of 2012
# * p = 3
#     * % change in the US market
#     * % change in the British market
#     * % change in the German market

# %% [markdown]
# **3. We now revisit the bias-variance decomposition.**
#
# **a.** Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error curves, on a single plot, as we go from less flexible statistical learning methods towards more flexible approaches. The x-axis should represent the amount of flexibility in the method, and the y-axis should represent the values for each curve. There should be five curves. Make sure to label each one.
#
# ## TODO - make nice sketch describing phenomenon

# %%
x = np.linspace(-5, 10)
y = x**2

plt.xlabel('flexibility')
plt.plot(x, y)
#plt.plot(x, x)

# %%
x = np.arange(10)

plt.plot(x, x)
plt.plot(x, 2 * x)
plt.plot(x, 3 * x)
plt.plot(x, 4 * x)

plt.legend(['y = x', 'y = 2x', 'y = 3x', 'y = 4x'], loc='upper left')

plt.show()

# %% [markdown]
# [example plot](http://www-bcf.usc.edu/~gareth/ISL/Chapter2/2.12.pdf)

# %% [markdown]
# **4. You will now think of some real-life applications for statistical learning.**
#
# **a.** Describe three real-life applications in which _classification_ might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.
#
# > 1. Modeling whether a **user will click a link on a website**. The response would be click or no-click (qualitative). Some predictors may be length of time on site, number of previous clicks, and previous page. The goal of this application is prediction because we want to strategically place links to maximize clicks.
# 2. Modeling whether a **transaction is fradulent or not**. The response would be fraud or not fraud. Some predictors may be physical locations of transaction, items in the transaction, and whether the purchaser has made non-fradulent transactions in the past. The goal of this application can be inference because we want to learn how each individual variable affects the probability of fraud.
# 3. Modeling whether a **borrower will default on their loan**. The response would be default or not default. The predictors could be the borrower debt to credit ratio, the duration of credit, and loan balance. This can be prediction if we solely care about whether a borrower will default or not and could be inference if we are more interested in how each of the individual variable affects the probability of default.
#
# **b.** Describe three real-life applications in which _regression_ might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.
#
# > 1. Modeling the **price of a home**. The response variable could be the price (quantitative) of an individual home. The predictors could be square footage, zip code, and number of bedrooms. This can be prediction if we solely care about predicting the price of a home based on predictors and could be inference if we want to learn how the individual predictors influence the price.
# 2. Modeling the **distance of a celestial star**. The response would be the distance (in miles? lightyears?) of a star. The predictors could be color of star, size of star, and placement in the sky. This model could be prediction if you are trying to predict the distance of the star. This model could be inference if you are interested in how each of the individual variables affect the distance of a star.
# 3. Modeling the **time it takes for a car to go from stopping to a mile**. The response would be the time (seconds) it takes for a car to go a mile from a stoping position. The predictors could be horsepower, number of pistons, front/rear/all wheel drive, and transmission type. This application could be prediciton if you solely care about predicting the completion time based on the predictors. Or this application could be inference if you are interested in how individual variables affects the time of completion.
#
# **c.** Describe three real-life applications in which _cluster analysis_ might be useful.
#
# > 1. **Segmenting customer types** based on observable characteristics from purchase data. (i.e. big spenders, low spenders, price sensitive, etc.)
# 2. **Identify social groups** based on observable characteristics from social media data. (i.e. find groups of people based on there 'like', 'follows', 'retweets', etc.)
# 3. **Identifying groups of public companies** based on observable characterstics from SEC disclosures. (i.e. identify by sector, financing, company structure, etc.)

# %% [markdown]
# **5. What are the advantages and disadvantages of a very flexible (versus a less flexible) approach for regression or classification? Under what circumstances might a more flexible approach be preferred to a less flexible approach? When might a less flexible approach be preferred?**
#
# > The **advantages for a flexible approach** for regression or classification is that more flexible models can fit many different possible functional forms for *_f_*. Some of the **disadvantages for a more flexible approach** is that fitting a more flexible model requires estimating a greater number of parameters and that more complex (flexible) models can lead to a phenomenon known as _overfitting_ the data, which essentially means they follow the errors, or noise, too closely.
# A more flexible approach may be preferred if you have no concern for interpretability, but instead only care about prediction. (But you need to be careful not to overfit!)
# If we are mainly interested in inference, then less flexible models may be preferred as they are much more interpretable.

# %% [markdown]
# **6. Describe the differences between a parametric and a non-parametric statistical learning approach. What are the advantages of a parametric approach to regression or classification (as opposed to a non-parametric approach)? What are its disadvantages?**
#
# > The **advantages of a parametric** approach to regression or classification are that it reduces the problem of estimating *_f_* down to one of estimating a set of parameters. This beneficial because it is generally much easier to estimte a set of parameters that it is to fit an entirely arbitrary fuction of *_f_*. The potential **disadvantage of a parametric** approach is that the model we choose will usually not match the true unknown form of *_f_*. If the chosen model is too far from the true *_f_*, then our estimate will be poor.
# The **advantages of a non-parametric** approach is that by avoiding the assumption of a particular functional form for *_f_*, they have the potential to accurately fit a wider range of possible shapes for *_f_*. The **disadvantages of non-parametric** approaches is that since they do not reduce the problem of estimating *_f_* to a small number of parameters, a very large number of observations is required in order to obtain an accurate estimate for *_f_*.

# %% [markdown]
# **7. The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.**

# %%
df = pd.DataFrame([[1, 0, 3, 0, 'Red'],
                   [2, 2, 0, 0, 'Red'],
                   [3, 0, 1, 3, 'Red'],
                   [4, 0, 1, 2, 'Green'],
                   [5, -1, 0, 1, 'Green'],
                   [6, 1, 1, 1, 'Red']],
                  columns = ['Obs.','X1','X2','X3','Y'])
df
# Out:
#    Obs.  X1  X2  X3      Y
# 0     1   0   3   0    Red
# 1     2   2   0   0    Red
# 2     3   0   1   3    Red
# 3     4   0   1   2  Green
# 4     5  -1   0   1  Green
# 5     6   1   1   1    Red

# %% [markdown]
# **Suppose we wish to use this data set to make a prediction for Y when X1 = X2 = X3 = 0 using K-nearest neighbors.**
#
# **a.** Compute the Euclidean distance between each observation and the test point, X1 = X2 = X3 = 0.

# %%
df['euc_dist_00'] = np.sqrt(((df.X1 - 0) ** 2) +
                            ((df.X2 - 0) ** 2) +
                            ((df.X3 - 0) ** 2))
df
# Out:
#    Obs.  X1  X2  X3      Y  euc_dist_00
# 0     1   0   3   0    Red     3.000000
# 1     2   2   0   0    Red     2.000000
# 2     3   0   1   3    Red     3.162278
# 3     4   0   1   2  Green     2.236068
# 4     5  -1   0   1  Green     1.414214
# 5     6   1   1   1    Red     1.732051

# %% [markdown]
# **b.** What is our prediction with K=1? Why?
#
# > Our prediciton when K=1 is **Green** because the nearest single neighbor (K=1) is observation number 5.
#
# **c.** What is our prediction with K=3? Why?
#
# > Our prediction when K=3 is **Red** because of the 3 closest neighbors (K=3), 2 are Red (obs. # 6 and 2) and 1 is Green (obs. # 5). Therefore the majority class (2/3) is Red.
#
# **d.** If the Bayes decision boundary in this problem is highly non-linear, then would we expect the _best_ value for K to be large or small? Why?
#
# > We would expect the best value for K to be **small** because smaller K will find a more flexible decision boundary.

# %% [markdown]
# ## Applied
#
# **8.** Read `College.csv` into Python
#
# Note: we will import the data set from the book website.

# %%
df = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/College.csv')
df
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %% [markdown]
# **(c) i.** Use the `summary()` function to produce a numerical summary of the variables in the data set.
#
# **Note:** We will use the `describe` function in Python for the same effect.

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# To view the categorical variables from the data you use the following command.

# %%
df.describe(include='object')
# Out:
#            Unnamed: 0 Private
# count             777     777
# unique            777       2
# top     Virginia Tech     Yes
# freq                1     565

# %% [markdown]
# **(c) ii.** Use the `pairs()` function to produce a scatterplot matrix of the first ten columns or variables of the data. Recall that you can reference the first ten columns of a matrix A using `A[,1:10]`.
#
# **Note:** The `pairs()` function in R creates a scatterplot matrix (pg. 50). For the Python equivalent we will use the `scatter_matrix` in pandas. Documentation can be found [here.](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.plotting.scatter_matrix.html)
#
# Unlike R, Python does not natively support factors/categorical/objects when plotting a scatter matrix. If you want to plot the categorical variables you will need to convert them to integers. For instance, `Private` is categorical (Yes, No), you would need to convert that to numerical (0, 1) to plot it in a python scatter matrix. If a variable is not an integer it will not be seen in the plot.

# %%
pd.plotting.scatter_matrix(df.iloc[:, 0:10], figsize=(10,10))
plt.show()

# %% [markdown]
# **(c) iii.** Use the `plot()` function to produce side-by-side boxplots of `Outstate` versus `Private`.
#
# **Note:** Private is an object data type (qualitative), while Outstate is an int64 (quantitative).

# %%
df.boxplot(column='Outstate', by='Private', figsize=(8,6))
plt.show()

# %% [markdown]
# **(c) iv.** Create a new qualitative variable, called `Elite`, by binning the `Top10perc` variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.

# %%
df['Elite'] = ['Yes' if x > 50 else 'No' for x in df['Top10perc']]
df
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %% [markdown]
# Use the `summary()` function to see how many elite universities there are.
#
# **Note:** We will use the `describe` or `value_counts` function in Python.

# %%
df['Elite'].describe()
# Out:
# count     777
# unique      2
# top        No
# freq      699
# Name: Elite, dtype: object

# %%
print(df['Elite'].value_counts())
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %% [markdown]
# Now use the `plot()` function to produce side-by-side boxplots of `Outstate` versus `Elite`.

# %%
df.boxplot(column='Outstate', by='Elite', figsize=(8,6))
plt.show()

# %% [markdown]
# **(c) v.** Use the `hist()` function to produce some histograms with differing numbers of bins for a few of the quantitative variables.
#
# **Note:** We will use [`pandas.DataFrame.hist`](https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.DataFrame.hist.html)

# %%
df.hist(column='Apps')
df.hist(column='Apps', bins=30)
plt.show()

# %%
df['Apps'].hist(bins=30, figsize=(10,6))
df['Accept'].hist(bins=30)
df['Enroll'].hist(bins=30)
plt.show()

# %%
df['F.Undergrad'].hist(bins=30, figsize=(10,6))
df['P.Undergrad'].hist(bins=30)
plt.show()

# %% [markdown]
# **(c vi.)** Continue exploring the data, and provide a brief summary of what you discover.

# %%
df.plot.scatter(x='Accept', y='Top10perc', figsize=(10,6))
plt.show()

# %%
# create an acceptance rate variable

df['Accept_rate'] = df['Accept']/df['Apps']

# %%
df.plot.scatter(x='Accept_rate', y='Grad.Rate', 
                c='Expend', colormap='jet' ,figsize=(10,6))
plt.show()

# %% [markdown]
# Higher graduation rate correlates to higher instructional expenditure per student and lower acceptance rate.

# %%
df.plot.scatter(x='Accept', y='Apps', figsize=(10,6),
               c='Top10perc', colormap='jet')
plt.show()

# %% [markdown]
# Colleges with a high number of applicants and a low number of offers of acceptance tend to have a higher number of new students from the top 10% of their high school class.

# %% [markdown]
# **9. This exercise involves the `Auto` data set studied in the lab. Make sure that the missing values have been removed from the data.**

# %%
# In this data set missing values are encoded as '?' so we will need to
#  pass that to the `na_values` parameter.

df = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Auto.csv'
                 , na_values='?')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# 5    15.0          8         429.0       198.0    4341          10.0    70
# 6    14.0          8         454.0       220.0    4354           9.0    70
# 7    14.0          8         440.0       215.0    4312           8.5    70
# 8    14.0          8         455.0       225.0    4425          10.0    70
# 9    15.0          8         390.0       190.0    3850           8.5    70
# 10   15.0          8         383.0       170.0    3563          10.0    70
# ...

# %%
# check for missing values
df.isnull().sum()

# 5 obs. are missing horsepower
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      5
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
# Drop the 5 rows with missing data.

df = df.dropna()
df.shape
# Out:
# (392, 9)

# %% [markdown]
# **(a) Which of the predictors are quantitative, and which are qualitative?**
#
# The quantitative predictors are mpg, cylinders, displacement, horsepower, weight, and acceleration.
#
# The qualitative predictors are name, origin, and year.

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
df.describe(include='object')
# Out:
#                name
# count           392
# unique          301
# top     amc matador
# freq              5

# %% [markdown]
# **(b)** What is the range of each quantitative predictor?
#
# Min and Max for each predictor can be found with `describe` function.

# %%
df.describe().loc[['min','max']]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# min   9.0        3.0          68.0        46.0  1613.0           8.0  70.0
# max  46.6        8.0         455.0       230.0  5140.0          24.8  82.0
#
#      origin
# min     1.0
# max     3.0

# %% [markdown]
# **(c)** What is the mean and standard deviation of each quantitative variable?

# %%
df.describe().loc[['mean','std']]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# mean  23.445918   5.471939    194.411990  104.469388  2977.584184
# std    7.805007   1.705783    104.644004   38.491160   849.402560
#
#       acceleration       year    origin
# mean     15.541327  75.979592  1.576531
# std       2.758864   3.683737  0.805518

# %% [markdown]
# **(d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?**

# %%
df_subset = df.drop(df.index[9:85])
df_subset.shape
# Out:
# (316, 9)

# %%
df_subset.describe().loc[['min','max','mean','std']]
# Out:
#             mpg  cylinders  displacement  horsepower       weight  \
# min   11.000000   3.000000     68.000000   46.000000  1649.000000
# max   46.600000   8.000000    455.000000  230.000000  4997.000000
# mean  24.404430   5.373418    187.240506  100.721519  2935.971519
# std    7.867283   1.654179     99.678367   35.708853   811.300208
#
#       acceleration       year    origin
# min       8.500000  70.000000  1.000000
# max      24.800000  82.000000  3.000000
# mean     15.726899  77.145570  1.601266
# std       2.693721   3.106217  0.819910

# %% [markdown]
# **(e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.**

# %%
df.hist(column=['cylinders','mpg', 'horsepower'],figsize=(10,4)
       , layout=(1,3))
plt.show()

# %%
df.plot.scatter(x='cylinders', y='mpg', 
                c='horsepower', colormap='jet' ,figsize=(10,6))
plt.show()

# %% [markdown]
# Greater number of cylinders and greater horsepower corresponds with lower mpg.

# %%
df.plot.scatter(x='mpg', y='acceleration', figsize=(10,6))
plt.show()

# %%
df.hist(column='mpg', by='year', bins=10, figsize=(8,8), 
        sharex=True)
plt.show()

# %% [markdown]
# The year 1980 seemed to bring a jump in mpg. Could there have been rules that took effect that year?

# %%
df.boxplot(column='mpg', by='year', figsize=(8,6))
plt.show()

# %% [markdown]
# Mpg improved as years progress.

# %% [markdown]
# **(f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.**
#
# Horsepower, cylinders, acceleration and maybe even year may be useful in prediction mpg. The greater the horsepower and cylinders the lower the mpg. The higher the acceleration the greater the mpg. Also, as years progress the mpg increases.

# %% [markdown]
# **10. This exercise involves the `Boston` housing data set.**
#
# **(a)** Load the `Boston` data set. How many rows and columns? What do the rows and columns represent?

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')
df.head(10)
# Out:
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
print("There are " + str(df.shape[0]) + " rows and " 
      + str(df.shape[1]) + " columns.")
print("Shape of dataframe: " + str(df.shape))
# Out:
# There are 506 rows and 14 columns.
# Shape of dataframe: (506, 14)

# %% [markdown]
# Information about the data set can be found [here.](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html)
#
# The rows are observations of housing units. The columns are described as follows:
#
# * CRIM - per capita crime rate by town
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# * INDUS - proportion of non-retail business acres per town.
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * NOX - nitric oxides concentration (parts per 10 million)
# * RM - average number of rooms per dwelling
# * AGE - proportion of owner-occupied units built prior to 1940
# * DIS - weighted distances to five Boston employment centres
# * RAD - index of accessibility to radial highways
# * TAX - full-value property-tax rate per `$10,000`
# * PTRATIO - pupil-teacher ratio by town
# * B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# * LSTAT - % lower status of the population
# * MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# **(b) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.**

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.plot.scatter(x='ptratio', y='medv', 
                c='crim', colormap='jet' ,figsize=(10,6))
plt.show()

# %%
df.plot.scatter(x='ptratio', y='crim',figsize=(10,6))
plt.show()

# %% [markdown]
# A pupil-teacher ratio by town suspiciously around 20 seems to correlate with a spike in per capita crime rate. This is suspicious because surrounding putpil-teacher ratio's don't share this behaviour. Could stem from how the data was collected.

# %%
df.plot(x='age', y='medv', kind='hexbin', gridsize=20, figsize=(8,6))
plt.show()

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15))
plt.show()

# %% [markdown]
# Crim correlates with indus, age, dis, lstat, etc.
# Rms correlates with lstat.
# Nox correlates with indus, dis, lstat.

# %% [markdown]
# **(c) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.**
#
# Per capita crime rate is associated indus (proportion of non-retail business acres per town), nox (nitric oxides concentration), and lstat (% lower status of the population).

# %% [markdown]
# **(d) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.**

# %%
df.hist(column='crim', bins=20, figsize=(8,6))
plt.show()

# %% [markdown]
# Most suburbs have a low cribe rate per capita, but some are in the 20-80 range.

# %%
df.hist(column='tax', bins=20, figsize=(8,6))
plt.show()

# %% [markdown]
# The are some suburbs with a much higher tax rate than the rest of the suburbs. Most suburbs are below 500, but ther are ~130 with a tax rate in the high 600's.

# %%
df.hist(column='ptratio', bins=25, figsize=(8,6))
plt.show()

# %% [markdown]
# A large portion of suburbs (~140) have a parent teacher ratio of ~20.

# %% [markdown]
# **(e) How many of the suburbs in this data set bound the Charles river?**
#
# Remember: CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# 35 suburbs (6.9%) bound the Charles river.

# %%
print(df.chas.value_counts())
print(df.chas.value_counts(normalize=True))
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64
# 0    0.93083
# 1    0.06917
# Name: chas, dtype: float64

# %% [markdown]
# **(f) What is the median pupil-teacher ratio among the towns in this data set?**
#
# 19.05

# %%
df['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# **(g) Which suburb of Boston has lowest median value of owner-occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.**
#
# Crim, nox, age, dis, rad, tax, b, and lstat are higher than average. So these appear to be areas with relative high crime rates, older homes, high taxes and higher portion of lower status residents.

# %%
# find the min medv.

df['medv'].min()
# Out:
# 5.0

# %%
# get values of other predictors with the min medv.

print(df.loc[df['medv'] == 5])
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio       b  lstat  medv
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0

# %%
# alternative method to get min medv

df[df['medv'] == min(df['medv'])]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio       b  lstat  medv
# 398     20.2  396.90  30.59   5.0
# 405     20.2  384.97  22.98   5.0

# %%
# get predictors of full data to compare.

df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# **(h) In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.**
#
# Higher medv, lower lstat.

# %%
print(df.loc[df.rm > 7].shape)
# Out:
# (64, 14)

# %%
df[df['rm'] > 7].shape
# Out:
# (64, 14)

# %%
(df['rm'] > 7).sum()
# Out:
# 64

# %%
print(df.loc[df.rm > 8].shape)
# Out:
# (13, 14)

# %%
df[df['rm'] > 8].shape
# Out:
# (13, 14)

# %%
(df['rm'] > 8).sum()
# Out:
# 13

# %%
# decription of predictors with greater than 8 rooms

df[df['rm'] > 8].describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio           b  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000   13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538  385.210769
# std    24.608723   1.883955   5.332532  110.971063   2.410580   10.529359
# ...

# %%
# view the areas with less that 8 rooms to compare

df[df['rm'] <= 8].describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  493.000000  493.000000  493.000000  493.000000  493.000000  493.000000
# mean     3.689855   11.304260   11.243793    0.066937    0.555103    6.230211
# std      8.700255   23.265932    6.866735    0.250167    0.116481    0.624223
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.080140    0.000000    5.190000    0.000000    0.449000    5.879000
# 50%      0.245220    0.000000    9.690000    0.000000    0.538000    6.185000
# 75%      3.774980   12.500000   18.100000    0.000000    0.624000    6.575000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    7.929000
#
#               age         dis         rad         tax     ptratio           b  \
# count  493.000000  493.000000  493.000000  493.000000  493.000000  493.000000
# mean    68.496755    3.804663    9.604462  410.430020   18.510751  355.921542
# ...
